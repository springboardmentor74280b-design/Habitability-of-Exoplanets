# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Dataset/phl_exoplanet_catalog_2019.csv')
df.head()
# Out:
#        P_NAME  P_STATUS      P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# 0    11 Com b       3.0  6165.86330        -476.74200         476.74200
# 1    11 UMi b       3.0  4684.78480        -794.57001         794.57001
# 2    14 And b       3.0  1525.57440               NaN               NaN
# 3    14 Her b       3.0  1481.07850         -47.67420          47.67420
# 4  16 Cyg B b       3.0   565.73385         -25.42624          25.42624
#
#    P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX  P_YEAR   P_UPDATED  \
# 0       NaN                 NaN                 NaN    2007  2014-05-14
# 1       NaN                 NaN                 NaN    2009  2018-09-06
# 2       NaN                 NaN                 NaN    2008  2014-05-14
# 3       NaN                 NaN                 NaN    2002  2018-09-06
# 4       NaN                 NaN                 NaN    1996  2018-09-06
#
#      P_PERIOD  P_PERIOD_ERROR_MIN  P_PERIOD_ERROR_MAX  P_SEMI_MAJOR_AXIS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4048 entries, 0 to 4047
# Columns: 112 entries, P_NAME to P_SEMI_MAJOR_AXIS_EST
# dtypes: float64(94), int64(4), object(14)
# memory usage: 3.5+ MB

# %%
df.shape
# Out:
# (4048, 112)

# %%
df.columns
# Out:
# Index(['P_NAME', 'P_STATUS', 'P_MASS', 'P_MASS_ERROR_MIN', 'P_MASS_ERROR_MAX',
#        'P_RADIUS', 'P_RADIUS_ERROR_MIN', 'P_RADIUS_ERROR_MAX', 'P_YEAR',
#        'P_UPDATED',
#        ...
#        'P_HABZONE_CON', 'P_TYPE_TEMP', 'P_HABITABLE', 'P_ESI',
#        'S_CONSTELLATION', 'S_CONSTELLATION_ABR', 'S_CONSTELLATION_ENG',
#        'P_RADIUS_EST', 'P_MASS_EST', 'P_SEMI_MAJOR_AXIS_EST'],
#       dtype='object', length=112)

# %%
df.dtypes
# Out:
# P_NAME                    object
# P_STATUS                 float64
# P_MASS                   float64
# P_MASS_ERROR_MIN         float64
# P_MASS_ERROR_MAX         float64
#                           ...
# S_CONSTELLATION_ABR       object
# S_CONSTELLATION_ENG       object
# P_RADIUS_EST             float64
# P_MASS_EST               float64
# P_SEMI_MAJOR_AXIS_EST    float64
# Length: 112, dtype: object

# %%
df.columns
# Out:
# Index(['P_NAME', 'P_STATUS', 'P_MASS', 'P_MASS_ERROR_MIN', 'P_MASS_ERROR_MAX',
#        'P_RADIUS', 'P_RADIUS_ERROR_MIN', 'P_RADIUS_ERROR_MAX', 'P_YEAR',
#        'P_UPDATED',
#        ...
#        'P_TYPE_TEMP', 'P_HABITABLE', 'P_ESI', 'S_CONSTELLATION',
#        'S_CONSTELLATION_ABR', 'S_CONSTELLATION_ENG', 'P_RADIUS_EST',
#        'P_MASS_EST', 'P_SEMI_MAJOR_AXIS_EST', 'Unnamed: 115'],
#       dtype='object', length=106)

# %%
df.describe()
# Out:
#        P_STATUS        P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# count    4048.0   1598.000000       1467.000000       1467.000000
# mean        3.0    798.384920       -152.292232        190.289692
# std         0.0   1406.808654        783.366353       1082.061976
# min         3.0      0.019070     -24965.390000          0.000000
# 25%         3.0     26.548968        -79.457001          4.449592
# 50%         3.0    273.332080        -24.154928         25.108412
# 75%         3.0    806.488560         -4.392383         85.813561
# max         3.0  17668.059000          0.270000      26630.808000
#
#           P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX       P_YEAR  \
# count  3139.000000         3105.000000         3105.000000  4048.000000
# mean      4.191426           -0.483990            0.621867  2014.212945
# std       4.776830            1.409048            2.007592     3.704839
# min       0.336300          -54.592700            0.000000  1989.000000
# ...

# %%
miss_count = df.isnull().sum()
miss_count.sort_values(ascending=False)
# Out:
# P_ATMOSPHERE           4048
# P_ALT_NAMES            4048
# P_DETECTION_RADIUS     4048
# P_GEO_ALBEDO           4048
# P_DETECTION_MASS       4048
#                        ...
# P_HABITABLE               0
# S_CONSTELLATION_ABR       0
# S_CONSTELLATION_ENG       0
# P_RADIUS_EST              0
# P_MASS_EST                0
# Length: 112, dtype: int64

# %%
col_drop = miss_count[miss_count == len(df)]
col_drop
# Out:
# P_GEO_ALBEDO          4048
# P_DETECTION_MASS      4048
# P_DETECTION_RADIUS    4048
# P_ALT_NAMES           4048
# P_ATMOSPHERE          4048
# S_DISC                4048
# S_MAGNETIC_FIELD      4048
# dtype: int64

# %%
new_df = df.drop(columns=col_drop.index)
new_df.shape
# Out:
# (4048, 105)

# %%
num_col = new_df.select_dtypes(include=['int64', 'float64']).columns
df[num_col].describe()
# Out:
#        P_STATUS        P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# count    4048.0   1598.000000       1467.000000       1467.000000
# mean        3.0    798.384920       -152.292232        190.289692
# std         0.0   1406.808654        783.366353       1082.061976
# min         3.0      0.019070     -24965.390000          0.000000
# 25%         3.0     26.548968        -79.457001          4.449592
# 50%         3.0    273.332080        -24.154928         25.108412
# 75%         3.0    806.488560         -4.392383         85.813561
# max         3.0  17668.059000          0.270000      26630.808000
#
#           P_RADIUS  P_RADIUS_ERROR_MIN  P_RADIUS_ERROR_MAX       P_YEAR  \
# count  3139.000000         3105.000000         3105.000000  4048.000000
# mean      4.191426           -0.483990            0.621867  2014.212945
# std       4.776830            1.409048            2.007592     3.704839
# min       0.336300          -54.592700            0.000000  1989.000000
# ...

# %%
new_df.describe(include='object')
# Out:
#           P_NAME   P_UPDATED P_DETECTION     S_NAME S_TYPE S_ALT_NAMES  \
# count       4048        4048        4048       4048   1370        4048
# unique      4048         184          10       3010    210         584
# top     11 Com b  2016-05-10     Transit  Kepler-90   G0 V           ,
# freq           1        1282        3114          8     56        3269
#
#         P_TYPE S_TYPE_TEMP         S_RA_T         S_DEC_T P_TYPE_TEMP  \
# count     4031        3912           4048            4048        3721
# unique       6           7           3010            3010           3
# top     Jovian           G  18 57 44.0416  +49 18 18.5796         Hot
# freq      1302        1792              8               8        3341
#
#        S_CONSTELLATION S_CONSTELLATION_ABR S_CONSTELLATION_ENG
# count             4048                4048                4048
# unique              88                  88                  88
# top             Cygnus                 Cyg                Swan
# ...

# %%
new_df[num_col].nunique()
# Out:
# P_STATUS                    1
# P_MASS                   1080
# P_MASS_ERROR_MIN          473
# P_MASS_ERROR_MAX          474
# P_RADIUS                  763
#                          ...
# P_HABITABLE                 3
# P_ESI                    3720
# P_RADIUS_EST             1472
# P_MASS_EST               1549
# P_SEMI_MAJOR_AXIS_EST    3020
# Length: 91, dtype: int64

# %%
new_df[new_df.select_dtypes(include=['object']).columns].nunique()
# Out:
# P_NAME                 4048
# P_UPDATED               184
# P_DETECTION              10
# S_NAME                 3010
# S_TYPE                  210
# S_ALT_NAMES             584
# P_TYPE                    6
# S_TYPE_TEMP               7
# S_RA_T                 3010
# S_DEC_T                3010
# P_TYPE_TEMP               3
# S_CONSTELLATION          88
# S_CONSTELLATION_ABR      88
# S_CONSTELLATION_ENG      88
# dtype: int64

# %%
new_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
q1 = new_df[num_col].quantile(0.25)
q3 = new_df[num_col].quantile(0.75)
iqr = q3 - q1
iqr
# Out:
# P_STATUS                   0.000000
# P_MASS                   779.939592
# P_MASS_ERROR_MIN          75.064618
# P_MASS_ERROR_MAX          81.363969
# P_RADIUS                   1.984170
#                             ...
# P_HABITABLE                0.000000
# P_ESI                      0.106363
# P_RADIUS_EST              10.066580
# P_MASS_EST               145.751059
# P_SEMI_MAJOR_AXIS_EST      0.207507
# Length: 91, dtype: float64

# %%
outliers = ((new_df[num_col] < (q1 - 1.5 * iqr)) | (new_df[num_col] > (q3 + 1.5 * iqr)))
out_count = outliers.sum().sort_values(ascending=False)
print('The count of outliiers :\n',out_count)
# Out:
# The count of outliiers :
#  P_PERIOD_ERROR_MIN        798
# P_PERIOD_ERROR_MAX        794
# P_MASS_EST                715
# P_APASTRON                695
# P_PERIOD                  691
#                          ...
# P_OMEGA                     1
# P_STATUS                    0
# P_TEMP_MEASURED             0
# P_GEO_ALBEDO_ERROR_MAX      0
# P_GEO_ALBEDO_ERROR_MIN      0
# Length: 91, dtype: int64

# %%
df[num_col].skew().sort_values(ascending=False)
# Out:
# P_PERIOD                       62.170001
# P_PERIOD_ERROR_MAX             61.467191
# P_FLUX_MIN                     45.714727
# P_FLUX                         45.699102
# S_MASS_ERROR_MAX               45.649624
#                                  ...
# P_SEMI_MAJOR_AXIS_ERROR_MIN   -27.083874
# S_AGE                         -31.843343
# S_RADIUS_ERROR_MIN            -32.113850
# S_MASS_ERROR_MIN              -45.449160
# P_PERIOD_ERROR_MIN            -60.895945
# Length: 91, dtype: float64

# %%
corr = new_df.corr(numeric_only=True)
corr
# Out:
#                        P_STATUS    P_MASS  P_MASS_ERROR_MIN  P_MASS_ERROR_MAX  \
# P_STATUS                    NaN       NaN               NaN               NaN
# P_MASS                      NaN  1.000000         -0.586394          0.512819
# P_MASS_ERROR_MIN            NaN -0.586394          1.000000         -0.847396
# P_MASS_ERROR_MAX            NaN  0.512819         -0.847396          1.000000
# P_RADIUS                    NaN  0.243671         -0.218779          0.090935
# ...                         ...       ...               ...               ...
# P_HABITABLE                 NaN -0.064295          0.022998         -0.020819
# P_ESI                       NaN -0.141129          0.080344         -0.072911
# P_RADIUS_EST                NaN  0.260319         -0.115873          0.092648
# P_MASS_EST                  NaN  1.000000         -0.586394          0.512819
# P_SEMI_MAJOR_AXIS_EST       NaN  0.212207         -0.099808          0.069684
#
# ...

# %%
new_df.columns
# Out:
# Index(['P_NAME', 'P_STATUS', 'P_MASS', 'P_MASS_ERROR_MIN', 'P_MASS_ERROR_MAX',
#        'P_RADIUS', 'P_RADIUS_ERROR_MIN', 'P_RADIUS_ERROR_MAX', 'P_YEAR',
#        'P_UPDATED',
#        ...
#        'P_HABZONE_CON', 'P_TYPE_TEMP', 'P_HABITABLE', 'P_ESI',
#        'S_CONSTELLATION', 'S_CONSTELLATION_ABR', 'S_CONSTELLATION_ENG',
#        'P_RADIUS_EST', 'P_MASS_EST', 'P_SEMI_MAJOR_AXIS_EST'],
#       dtype='object', length=105)
